# %%
# !pip install opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install opencv-python-headless
# Out:
# ...
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\annu\\Object-detection\\Lib\\site-packages\\cv2\\cv2.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\annu\Object-detection\Scripts\python.exe

# %%
# !C:\Users\annu\Object-detection\Scripts\python.exe -m pip install opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
import uuid

# %%
import os
import time

# %% [markdown]
# # Define image to collect

# %%
labels = ['thumpsup' , 'Thankyou', 'Boo','livelong']
num_img = 5

# %% [markdown]
# # Setup folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # Capture images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(num_img):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Image labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# ...
#   Obtaining dependency information for pyqt5 from https://files.pythonhosted.org/packages/56/d5/68eb9f3d19ce65df01b6c7b7a577ad3bbc9ab3a5dd3491a4756e71838ec9/PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/12/8c/7d47cfc0d04fd4e3639ec7e1c96c2561d5e890eb900de8f76eea75e0964a/lxml-5.3.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for PyQt5-sip<13,>=12.15 from https://files.pythonhosted.org/packages/24/c1/50fc7301aa39a50f451fc1b6b219e778c540a823fe9533a57b4793c859fd/PyQt5_sip-12.17.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for PyQt5-Qt5<5.16.0,>=5.15.2 from https://files.pythonhosted.org/packages/37/97/5d3b222b924fa2ed4c2488925155cd0b03fd5d09ee1cfcf7c553c11c9f66/PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
# ...

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}
# Out:
# Cloning into 'Tensorflow\labelimg'...
# error: RPC failed; curl 56 Recv failure: Connection was reset
# error: 1524 bytes of body are still expected
# fetch-pack: unexpected disconnect while reading sideband packet
# fatal: early EOF
# fatal: fetch-pack: invalid index-pack output

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# C:\Users\annu\anaconda3\Scripts\pyrcc5: File does not exist 'resources.qrc'

# %%
import os
print(os.listdir("C:/Users/annu/Object-detection"))
# Out:
# ['.ipynb_checkpoints', 'etc', 'ImageLabelling.ipynb', 'Include', 'Lib', 'off', 'pyvenv.cfg', 'Scripts', 'share', 'Tensorflow']

# %%
import shutil
shutil.rmtree("C:/Users/annu/Object-detection/Tensorflow/labelImg", ignore_errors=True)

# %%
# !git clone https://github.com/heartexlabs/labelImg.git C:/Users/annu/Object-detection/Tensorflow/labelImg
# !pip install -r C:/Users/annu/Object-detection/Tensorflow /labelImg/requirements/requirements-windows.txt
# Out:
# Cloning into 'C:/Users/annu/Object-detection/Tensorflow/labelImg'...
# ERROR: Invalid requirement: '/labelImg/requirements/requirements-windows.txt'

# %%
# !cd C:/Users/annu/Object-detection/Tensorflow/labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !python C:/Users/annu/Object-detection/Tensorflow/labelImg/labelImg.py

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# C:\Users\annu\anaconda3\Scripts\pyrcc5: File does not exist 'resources.qrc'

# %%
import os
print(os.listdir("C:/Users/annu/Object-detection/Tensorflow/labelImg"))
# Out:
# ['.git', '.github', '.gitignore', 'build-tools', 'CONTRIBUTING.rst', 'data', 'demo', 'HISTORY.rst', 'issue_template.md', 'labelImg.py', 'libs', 'LICENSE', 'Makefile', 'MANIFEST.in', 'readme', 'README.rst', 'requirements', 'resources', 'resources.qrc', 'setup.cfg', 'setup.py', 'tests', 'tools', '__init__.py']

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# C:\Users\annu\anaconda3\Scripts\pyrcc5: File does not exist 'resources.qrc'

# %%
# !pip install pyqt5

# %%
import os

LABELIMG_PATH = "C:/Users/annu/Object-detection/Tensorflow/labelImg"
qrc_path = os.path.join(LABELIMG_PATH, "resources.qrc")

if os.path.exists(qrc_path):
    print("✅ resources.qrc file found!")
else:
    print("❌ resources.qrc file is missing!")
# Out:
# ✅ resources.qrc file found!

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:C:\Users\annu\Object-detection\Tensorflow\workspace\images\collectedimages\Boo\Boo.4672c2ef-0007-11f0-9180-c01850a265ff.jpg -> Annotation:C:/Users/annu/Object-detection/Tensorflow/workspace/images/collectedimages/Boo\Boo.4672c2ef-0007-11f0-9180-c01850a265ff.xml
# Image:C:\Users\annu\Object-detection\Tensorflow\workspace\images\collectedimages\Boo\Boo.1be82d02-0008-11f0-a6bf-c01850a265ff.jpg -> Annotation:C:/Users/annu/Object-detection/Tensorflow/workspace/images/collectedimages/Boo\Boo.1be82d02-0008-11f0-a6bf-c01850a265ff.xml
# Image:C:\Users\annu\Object-detection\Tensorflow\workspace\images\collectedimages\Boo\Boo.1d1b9cde-0008-11f0-92f4-c01850a265ff.jpg -> Annotation:C:/Users/annu/Object-detection/Tensorflow/workspace/images/collectedimages/Boo\Boo.1d1b9cde-0008-11f0-92f4-c01850a265ff.xml
# ...

# %% [markdown]
# # Move them into a Training and Testing Partition

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
